
}

# Create a DataFrame
df = pd.DataFrame(data)

# Plotting the data
plt.figure(figsize=(12, 8))
for col in df.columns[1:]:
    plt.plot(df['Year'], df[col], label=col)

plt.title("Consumer Price Indices in Georgia (2010=100)")
plt.xlabel("Year")
plt.ylabel("Index")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Extract indices for months I and XII
index_jan = df['I']
index_dec = df['XII']

# Calculate the rate of change
rate_of_change = (index_dec.iloc[-1] - index_jan.iloc[0]) / (df['Year'].iloc[-1] - df['Year'].iloc[0])

print(f"ცვლილების რაციონი პირველ და მეთორმეტე თვეებს შორის არის დაახლოებით {rate_of_change:.4f} ყოველწლიურად.")
# Out:
# ცვლილების რაციონი პირველ და მეთორმეტე თვეებს შორის არის დაახლოებით 5.4435 ყოველწლიურად.

# %%
# Provided data
data_avg_12_prev_12 = {
    'Year': list(range(2014, 2024)),
    'I': [99.9, 102.9, 104.4, 102.0, 106.1, 102.4, 105.2, 104.9, 110.5, 111.5],
    'II': [100.3, 102.8, 104.7, 102.0, 105.8, 102.4, 105.6, 104.7, 111.3, 111.1],
    'III': [100.8, 102.7, 104.8, 102.1, 105.6, 102.5, 105.8, 104.8, 111.7, 110.5],
    'IV': [101.2, 102.6, 104.9, 102.4, 105.3, 102.6, 106.0, 104.8, 112.2, 109.6],
    'V': [101.4, 102.7, 104.8, 102.8, 104.9, 102.8, 106.1, 104.9, 112.7, 108.6],
    'VI': [101.6, 102.9, 104.5, 103.2, 104.5, 103.0, 106.3, 105.2, 112.9, 107.6],
    'VII': [101.8, 103.1, 104.2, 103.6, 104.3, 103.1, 106.4, 105.8, 112.9, 106.6],
    'VIII': [102.2, 103.2, 103.8, 104.0, 104.1, 103.3, 106.3, 106.4, 112.7, 105.8],
    'IX': [102.7, 103.3, 103.4, 104.5, 103.8, 103.6, 106.1, 107.1, 112.6, 104.9],
    'X': [102.9, 103.5, 102.9, 105.1, 103.4, 104.0, 105.9, 107.9, 112.4, 104.1],
    'XI': [103.1, 103.8, 102.4, 105.6, 103.0, 104.4, 105.6, 108.6, 112.2, 103.2],
    'XII': [103.1, 104.0, 102.1, 106.0, 102.6, 104.9, 105.2, 109.6, 111.9, 102.5],
}

# Create a DataFrame
df_avg_12_prev_12 = pd.DataFrame(data_avg_12_prev_12)

# Plotting the data
plt.figure(figsize=(12, 8))
for col in df_avg_12_prev_12.columns[1:]:
    plt.plot(df_avg_12_prev_12['Year'], df_avg_12_prev_12[col], label=col)

plt.title("Consumer Price Indices in Georgia (12-month Average)")
plt.xlabel("Year")
plt.ylabel("Index")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Corrected data for 2014
data_2014 = {
    'Month': list(range(1, 13)),
    'I_2014': [99.9, 100.3, 100.8, 101.2, 101.4, 101.6, 101.8, 102.2, 102.7, 102.9, 103.1, 103.1],
}

# Create DataFrames
df_2024 = pd.DataFrame(data_2024)
df_2014 = pd.DataFrame(data_2014)

# Merge DataFrames on the 'Month' column
df_diff = pd.merge(df_2014, df_2024, on='Month')

# Calculate the differentiation for each month
df_diff['Difference'] = df_diff['I_2024'] - df_diff['I_2014']

# Display the resulting DataFrame
print(df_diff)
# Out:
#     Month  I_2014  I_2024  Difference
# 0       1    99.9   162.8        62.9
# 1       2   100.3   164.3        64.0
# 2       3   100.8   168.3        67.5
# 3       4   101.2   171.4        70.2
# 4       5   101.4   173.2        71.8
# 5       6   101.6   173.6        72.0
# 6       7   101.8   174.0        72.2
# 7       8   102.2   174.2        72.0
# 8       9   102.7   175.7        73.0
# 9      10   102.9   176.5        73.6
# 10     11   103.1   177.3        74.2
# 11     12   103.1   176.9        73.8

# %%
# Raw data
data = {
    "დასახელება": ["ბრინჯი", "წიწიბურა", "მანანის ბურღული", "ხორბლის პური", "მაკარონი და მაკარონის ნაწარმი",
                      "ვერმიშელი", "ნამცხვარი", "ვაფლი კრემით", "ორცხობილა", "ხაჭაპური საცხობში", "ხორბლის ფქვილი",
                      "სიმინდის ფქვილი", "ძროხის ხორცი", "ძროხის ხორცის ფარში", "ღორის ხორცი", "ქათმის ხორცი", "გაყინული ქათმის ხორცი",
                      "ქათმის ბარკლები", "შებოლილი ხორცი", "პელმენი (ნახევარფაბრიკატი)", "მოშუშული ხორცის კონსერვი", "შებოლილი ძეხვი",
                      "მოხარშული ძეხვი", "სოსისი", "ახალი თევზი", "გაყინული თევზი"],
    "I": [112.16, 98.80, 110.75, 119.20, 123.98, 122.20, 141.79, 136.13, 112.31, 118.18, 121.71, 183.22, 108.70, 109.44, 104.85, 113.45, 118.07, 106.91, 102.10, 113.08, 108.84, 110.77, 113.01, 101.46, 116.73, 107.19],
    "II": [108.57, 95.27, 114.06, 118.22, 120.76, 124.00, 140.81, 130.52, 116.23, 117.09, 114.08, 179.68, 111.10, 111.83, 106.14, 114.56, 119.76, 105.26, 102.53, 110.42, 106.57, 111.04, 111.31, 101.41, 113.96, 102.81],
    "III": [101.88, 83.77, 106.76, 115.53, 116.30, 115.10, 136.09, 131.00, 113.86, 115.99, 106.38, 167.93, 115.53, 113.72, 106.01, 107.94, 115.28, 102.83, 103.74, 109.19, 106.04, 106.32, 110.43, 102.16, 114.05, 102.73],
    "IV": [94.71, 74.59, 103.19, 108.08, 113.36, 105.96, 127.52, 117.01, 107.70, 114.82, 102.12, 135.44, 118.05, 113.97, 103.80, 101.83, 108.75, 97.95, 102.69, 105.48, 101.12, 99.92, 102.98, 102.03, 112.87, 99.16],
    "V": [88.82, 69.12, 99.69, 100.46, 102.42, 98.58, 122.66, 110.12, 108.64, 113.54, 100.46, 125.10, 117.79, 116.12, 102.54, 104.74, 107.90, 92.99, 107.10, 103.47, 106.24, 101.50, 104.03, 100.31, 112.94, 97.91],
    "VI": [89.43, 62.26, 97.88, 96.71, 102.01, 96.43, 116.12, 104.71, 105.34, 113.14, 96.71, 125.57, 117.79, 114.80, 102.36, 103.32, 102.27, 92.88, 100.17, 104.24, 100.37, 102.22, 102.86, 98.18, 114.72, 98.81],
    "VII": [91.36, 58.98, 95.28, 94.31, 101.95, 96.75, 114.55, 101.36, 102.85, 112.55, 94.31, 123.80, 116.95, 111.53, 100.56, 101.44, 95.11, 91.16, 103.99, 100.56, 101.44, 101.16, 102.12, 96.41, 111.79, 96.92],
    "VIII": [90.99, 57.15, 90.48, 90.59, 95.06, 92.88, 112.22, 98.21, 102.46, 110.78, 90.59, 117.29, 115.26, 110.22, 101.19, 99.13, 94.86, 100.81, 103.90, 101.88, 102.39, 100.81, 101.54, 98.33, 111.32, 98.27],
    "IX": [91.52, 55.17, 87.19, 90.51, 94.93, 93.75, 109.09, 97.76, 100.30, 111.47, 90.36, 112.87, 114.43, 109.72, 101.56, 99.80, 93.57, 99.59, 105.36, 104.58, 98.61, 99.04, 101.99, 92.81, 99.59, 100.11],
    "X": [89.68, 55.59, 87.33, 90.36, 93.11, 90.71, 105.23, 97.28, 101.97, 108.65, 90.53, 110.98, 115.14, 110.06, 100.65, 101.23, 92.64, 99.46, 102.35, 96.84, 99.04, 97.55, 102.53, 94.03, 99.46, 97.02],
    "XI": [90.61, 54.73, 85.92, 90.53, 93.05, 92.28, 98.29, 95.91, 99.47, 108.50, 91.65, 103.30, 113.76, 109.03, 100.39, 101.03, 89.27, 99.50, 105.30, 99.75, 97.55, 97.32, 101.78, 101.18, 99.50, 99.17],
    "XII": [89.57, 57.89, 84.05, 91.65, 92.88, 92.74, 104.60, 97.48, 97.91, 107.13, 91.69, 99.10, 113.89, 109.45, 99.65, 98.39, 91.69, 98.36, 104.15, 99.75, 96.86, None, None, None, None, None]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Set the product names as the index
df.set_index("დასახელება", inplace=True)

# Transpose the DataFrame for easier plotting
df = df.T

# Plot the data
plt.figure(figsize=(14, 8))
df.plot(marker='o')
plt.title("სამომხმარებლო ფასების დეტალური ინდექსები საქართველოში (2023)")
plt.xlabel("თვე")
plt.ylabel("ინდექსი")
plt.legend(title="პროდუქტი", bbox_to_anchor=(1.05, 1), loc='upper left')

# Display the plot
plt.tight_layout()
plt.show()

# %%
# Calculate yearly differences for "ხაჭაპური საცხობში"
product_name = "ხაჭაპური საცხობში"
df_diff = df[product_name].diff()

# Plot the differences
plt.figure(figsize=(10, 6))
df_diff.plot(kind='bar', color='skyblue')
plt.title(f"Yearly Differences for {product_name} (2023)")
plt.xlabel("Month")
plt.ylabel("Difference")
plt.show()
